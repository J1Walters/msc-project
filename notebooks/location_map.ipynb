# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sqlean as sqlite3
from functools import partial
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# ### Import Data

# %%
DATABASE_PATH = 'C:/University/6G7V0007_MSC_Project/Project/Data/joblistings_transformed.db'
con = sqlite3.connect(DATABASE_PATH)

# %%
job = pd.read_sql('SELECT * FROM job', con)
company = pd.read_sql('SELECT * FROM company', con)
website = pd.read_sql('SELECT * FROM website', con)
# Out:
# C:\Users\walte\AppData\Local\Temp\ipykernel_15304\1361633401.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   job = pd.read_sql('SELECT * FROM job', con)
# C:\Users\walte\AppData\Local\Temp\ipykernel_15304\1361633401.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   company = pd.read_sql('SELECT * FROM company', con)
# C:\Users\walte\AppData\Local\Temp\ipykernel_15304\1361633401.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   website = pd.read_sql('SELECT * FROM website', con)

# %%
job.set_index('id', inplace=True)
company.set_index('id', inplace=True)
website.set_index('id', inplace=True)

# %%
test = job.merge(company, left_on='company_id', right_index=True)

# %%
test.rename(columns={'name':'company_name'}, inplace=True)

# %%
test.head()
# Out:
#      website_id  company_id  \
# id
# 1             1           1
# 145           1           1
# 2             1           2
# 3             1           3
# 20            1           3
#
#                                                  title  \
# id
# 1    Graduate Electronics/Computer Science Software...
# 145                                   Project Engineer
# 2               Graduate Software Development Engineer
# 3                       Graduate Technology Consultant
# 20                         Graduate Software Developer
#
#                            location          pay  \
# id
# 1     Cirencester (Gloucestershire)      £30,000
# 145   Cirencester (Gloucestershire)  Competitive
# 2                            London  Competitive
# 3               Manchester (Hybrid)  Competitive
# 20   London and Manchester (Hybrid)  Competitive
#
#                                            description   timestamp  \
# id
# 1    About the role A unique opportunity to join a ...  2024-06-28
# 145  AccuLink Technology specialises in the design ...  2024-06-28
# 2    nFocus Graduate Academy Accelerate your career...  2024-06-28
# 3    About Arlanis Reply: Arlanis Reply is the Repl...  2024-06-28
# 20   About Arlanis Reply: Arlanis Reply is the Repl...  2024-06-28
#
#             company_name
# id
# 1    AccuLink Technology
# 145  AccuLink Technology
# 2                 nfocus
# 3                  Reply
# 20                 Reply

# %% [markdown]
# ### Clean location

# %%
# Remove characters in brackets
test['location'].replace(r'\(.*\)', '', regex=True, inplace=True)

# %%
# Remove postcodes
test['location'].replace(r'[A-Z]{2}[0-9]{1,2}[A-Z]?', '', regex=True, inplace=True)

# %%
# Strip whitespace
test['location'] = test['location'].str.strip()

# %%
# Map multiple locations to separate category
test['location'].replace(r'.*\sand\s.*', 'Multiple Locations', regex=True, inplace=True)
test['location'].replace(r'.*\s[&+]\s.*', 'Multiple Locations', regex=True, inplace=True)
test['location'].replace('Multiple UK Locations', 'Multiple Locations', inplace=True)
test['location'].replace('Multiple Worldwide Locations', 'Multiple Locations', inplace=True)

# %%
test['location'].unique()
# Out:
# array(['Cirencester', 'London', 'Manchester', 'Multiple Locations',
#        'Bristol', 'Cambridge', 'Geneva', 'Leeds', 'Warsaw', 'Brixworth',
#        'Glasgow', 'Barrow-in-Furness', 'Warton', 'Broad Oak', 'Brough',
#        'Scotstoun', 'Frimley', 'Filton', 'Weymouth', 'Barrow',
#        'Prestwick', 'Barrow-In-Furness', 'Chippenham', 'Pontyclun',
#        'Leatherhead', 'Redditch', 'Trafford Park', 'Stafford',
#        'Cheltenham', 'Didsbury', 'Solihull', 'Brighton', 'Remote',
#        'Malvern Hills', 'Chiswick', 'Chiswick Park', 'Luton',
#        'Crewe Toll, Edinburgh', 'Basildon', 'Southampton', 'Edinburgh',
#        'Leicester', 'Oxford', 'Tokyo', 'Bridgend', 'Burton',
#        'London, Chesterfield, Olney', 'Silverstone', 'Derby', 'Shipley',
#        'Poole', 'Newport', 'Newcastle', 'Norwich', 'West Midlands',
#        'Hemel Hempstead', 'Bath', 'Reading', 'Crownhill', 'Dublin',
#        'Eastbourne', 'Heathrow', 'Stockley Park, Uxbridge',
#        'Wolverhampton', 'Fareham', 'East Kilbride', 'Thame', 'Birmingham',
#        'Gravesend', 'Aylesbury', 'Sandhurst', 'Liverpool',
#        'Stratford-upon-Avon', 'Plymouth', 'Rosyth', 'Hong Kong',
#        'Stowmarket', 'Pencoed', 'Cardiff', 'Newcastle University',
#        'Telford', 'Durrington', 'Beckington', 'Exeter', 'Woodchester',
#        'Belfast', 'Bollington', 'Andover', 'Maidstone',
#        'London, Stevenage', 'Cramlington', 'Tiverton, Devon', 'Hull',
#        'Bradford', 'London W6', 'Waterlooville', 'Banbury', 'Swindon',
#        'London W1W', 'Marlow', 'Halifax', 'Kingston upon Thames',
#        '5th Floor, County Hall, London', 'Swansea',
#        'READING, Reading, B, United Kingdom', 'Killingworth', 'Hove',
#        'Great Yarmouth', 'Thames Ditton', 'Rugby', 'Sheffield',
#        'Twickenham', 'Be Amazed Media Ltd in London', 'Gillingham',
#        'Bailey Drive, Gillingham',
#        "Ray's House Business Centre, North Circular Road, London",
#        'Royal Tunbridge Wells', 'Kingston upon Hull',
#        '60 Bond Street, Kingston upon Hull', 'NETbuilder in Brighton',
#        'Guildford', 'Livingston', 'Warwick',
#        'Semcon House, Edgehill Drive, Warwick', 'Caterham', 'West End',
#        'Filey', 'Peterborough', 'Basingstoke', 'Nottingham', 'Witney',
#        'Bournemouth', 'Glasgow G2', 'Canary Wharf E14',
#        '33489-Argyle Street, Glasgow, 311-345 Argyle Street, Glasgow, GB, G2 8LP, Glasgow G2',
#        'Wembley', '401- 403 High Rd, London, Wembley', 'Birmingham B7',
#        'Milton', '21 Nuffield Way, Abingdon, Milton', 'Manchester M4',
#        'Liverpool L3', '20 Chapel Street, Liverpool L3', 'Rickmansworth',
#        'Biggin Hill', '62 Doughty St,  2JZ, London, London', 'Stirling',
#        'Wallace House 17-21 Maxwell Place, Stirling',
#        'Vintners’ Place, 68 Upper Thames Street, London', 'Harwell',
#        'Horsham', '3rd Floor Springfield House Springfield Road, Horsham',
#        '88 Leadenhall Street, London', 'Coventry', 'Southall',
#        'Farringdon', 'Farnborough', 'Aberdeen', 'Newcastle upon Tyne',
#        'Dundee', 'Birmingham B16', 'Manchester M3', 'Steeple Langford',
#        'Hebden Bridge', 'Southport', "King's Lynn", 'Chard',
#        'Cockermouth', 'Carrickfergus', 'London E1',
#        'Belgrave House, 76, London', 'Belper', 'Newmarket',
#        'Stoke-on-Trent', 'St Albans',
#        'Floor 10, 1 Lyric Square, Hammersmith, London W6', 'Cornwall',
#        'Wisley', 'Platform, New Station St, Leeds',
#        '122 Leadenhall Street, London', 'Yeovil', 'Bolton', 'London E14',
#        'Hartlebury', 'Unit 288, Hartlebury', 'Penryn', 'Portsmouth',
#        'Hounslow', 'Guiseley', 'London W1T', 'Colwyn Bay', 'Bangor',
#        'Inverkeithing', 'Budapest', 'Hursley', 'Salisbury',
#        '28 Bloomsbury Way, London', 'United Kingdom', 'Redruth',
#        'Kensington W8', 'Preston', 'Havant', 'Loughborough', 'Woking',
#        'Hammersmith', 'Wellington Square, Oxford',
#        '1 Rathbone Square, London', '3 Carburton Street, London',
#        'Northwich', 'Kings Langley', 'Saint Ives',
#        'Point Professional Recruitment Ltd in Saint Ives', 'North London',
#        'Sunderland', 'Lincoln', 'Esher', 'Hyde', 'Wales', 'Northampton',
#        'London N1C', 'Stevenage', '79 New Oxford Street, London',
#        'Sheffield S1', '49 Canal Street, Derby', 'Dumfries', 'Theale',
#        'Skipton', 'Fulham', 'Rhyl', 'Manchester M30', 'Surbiton',
#        'Birmingham B18', 'York',
#        '269 Great Ancoats St, M4 7DB, Manchester, Manchester M4',
#        'Gateshead', 'Blackburn', 'Croydon', 'Winnersh', 'Bracknell',
#        'Lancaster', 'High Wycombe', 'Warrington', 'Southend-on-Sea',
#        '1-11 John Adam Street, London', 'Wokingham', 'Derwent',
#        'Staines-upon-Thames', 'Milton Keynes', 'Leamington Spa',
#        'Lytham St. Annes', 'London W1K', 'Prudhoe', 'Douglas',
#        'London N19', 'Albert House,  9DD, London, London', 'Histon',
#        'London W1U', 'Harston', '6 Agar Street, London', 'Epsom', 'Fife',
#        'Culham', 'Wainbody', 'Colchester', 'Manchester M2', 'Scotland',
#        'Quedgeley', 'Hessle', 'London E3', 'Ilford', 'Elstree',
#        'Brighouse', 'Camberley', 'Kidlington', 'Hook', 'Middlesbrough',
#        'Gaydon', 'Ipswich', 'Manchester M16', '124 City Road, London',
#        '1 Surtees Way, Surtees Business Park, Stockton-on-Tees',
#        'V-Teck UK Ltd in Bridgend', '160 Fleet Street, London',
#        'Glasgow G3', 'Paddington', 'Capua HR Limited in London',
#        'Soho W1F', 'College Lane, Hatfield',
#        'Technical Resources in Bootle L30', '5 Box Road, Leicester',
#        'Swadlincote', 'PLS Solicitors, Atlantic Street, Altrincham',
#        'PlayAIO ltd in London', '1 Shakespeare Way, Whitchurch',
#        'MLN Security in Barking', 'Mercuna in Edinburgh', 'Tadley',
#        'guykat solutions ltd. , Faraday Wharf, Holt Street, Birmingham B7',
#        'Newbury', 'Unit 34, The Business Village, Cudworth, Barnsley S72',
#        '103, Oxford House, Oxford Rd, Manchester M1',
#        'Flat 3, 45 Albemarle Street, London W1S', 'Henley on Thames',
#        '130 Wood Street, London',
#        'Oxbridge International College Ltd in Stevenage', 'Richmond',
#        '17 Limeharbour, London',
#        '1st Floor Baird House, Liverpool Innovation Park, Merseyside, Liverpool L7',
#        'Cambourne', 'Welwyn Garden City',
#        'The Minstry, 79-81 Borough Road, London', 'Harrow', 'Doncaster',
#        '15 Cotswold Road, Sutton', 'Morley',
#        '4 Phoenix Square, Colchester', 'Alderley Edge',
#        '4it Recruitment Ltd in Manchester',
#        'prosperIS Recruitment Ltd in Monmouth', 'Didcot'], dtype=object)

# %%
test['location'].value_counts(sort=True).head(25)
# Out:
# location
# London                 289
# Remote                  86
# Multiple Locations      71
# Cambridge               38
# Leeds                   37
# Geneva                  36
# Manchester              25
# Bristol                 17
# Edinburgh               15
# Bridgend                14
# Budapest                12
# Oxford                  11
# Birmingham              10
# Belfast                  8
# Douglas                  8
# Derby                    8
# Newcastle upon Tyne      8
# Barrow-in-Furness        8
# Southampton              7
# Reading                  7
# Glasgow                  7
# Liverpool                6
# Bollington               6
# Aberdeen                 5
# Luton                    5
# Name: count, dtype: int64

# %%
geolocator = Nominatim(user_agent='msc_project')
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
test['full_loc'] = test['location'].apply(lambda x: partial(geocode, addressdetails=True) if x not in ('Remote') else None)

# %%
test['point'] = test['full_loc'].apply(lambda x: tuple(x.point) if x else None)

# %%
test['raw_loc'] = test['full_loc'].apply(lambda x: x.raw if x else None)

# %%
test[['location', 'full_loc', 'point', 'raw_loc']].tail(30)
# Out:
#                                      location  \
# id
# 1867                                   London
# 1872                                   London
# 1873                                   Remote
# 1874                               Nottingham
# 1876                           United Kingdom
# 1881                       Welwyn Garden City
# 1882  The Minstry, 79-81 Borough Road, London
# 1884                                   Harrow
# 1885                                  Croydon
# 1889                      Newcastle upon Tyne
# 1892                                   London
# 1893                               Birmingham
# 1894                                   London
# 1897                                  Bristol
# 1900                                  Preston
# 1901                                   Remote
# 1909                                Doncaster
# 1912                                  Cardiff
# 1914                 15 Cotswold Road, Sutton
# 1916                                   Morley
# 1917                                Bracknell
# 1920             4 Phoenix Square, Colchester
# 1921                                Guildford
# 1922                            Alderley Edge
# 1923                                   Remote
# 1926        4it Recruitment Ltd in Manchester
# 1927    prosperIS Recruitment Ltd in Monmouth
# 1928                                   Didcot
# 1929                                  Telford
# 1933                                 Chiswick
#
#                                                full_loc  \
# id
# 1867  (London, Greater London, England, United Kingd...
# 1872  (London, Greater London, England, United Kingd...
# 1873  (Remote, Coos County, Oregon, United States, (...
# 1874  (City of Nottingham, Nottinghamshire, England,...
# 1876         (United Kingdom, (54.7023545, -3.2765753))
# 1881  (Welwyn Garden City, Welwyn Hatfield, Hertford...
# 1882                                               None
# 1884  (London Borough of Harrow, London, Greater Lon...
# 1885  (London Borough of Croydon, London, Greater Lo...
# 1889  (Newcastle upon Tyne, North of Tyne, England, ...
# 1892  (London, Greater London, England, United Kingd...
# 1893  (Birmingham, West Midlands Combined Authority,...
# 1894  (London, Greater London, England, United Kingd...
# 1897  (Bristol, City of Bristol, West of England, En...
# 1900  (Preston, Lancashire, England, United Kingdom,...
# 1901  (Remote, Coos County, Oregon, United States, (...
# 1909  (Doncaster, South Yorkshire, England, United K...
# 1912  (Cardiff, Cymru / Wales, CF10 2AF, United King...
# 1914  (Cotswold Road, London Borough of Sutton, Lond...
# 1916  (Morley, Bar-le-Duc, Meuse, Grand Est, France ...
# 1917  (Bracknell, Bracknell Forest, England, United ...
# 1920  (Phoenix Square, Colchester Business Park, Hig...
# 1921  (Guildford, Surrey, England, United Kingdom, (...
# 1922  (Alderley Edge, Cheshire East, England, United...
# 1923  (Remote, Coos County, Oregon, United States, (...
# 1926                                               None
# 1927                                               None
# 1928  (Didcot, East Hagbourne, South Oxfordshire, Ox...
# 1929  (Telford, Telford and Wrekin, England, TF3 4HB...
# 1933  (Chiswick, Greater London, England, W4 5PS, Un...
#
#                                                point  \
# id
# 1867         (51.4893335, -0.14405508452768728, 0.0)
# 1872         (51.4893335, -0.14405508452768728, 0.0)
# 1873                 (43.0059455, -123.8925908, 0.0)
# 1874                   (52.9534193, -1.1496461, 0.0)
# 1876                   (54.7023545, -3.2765753, 0.0)
# 1881                   (51.8031083, -0.2068872, 0.0)
# 1882                                            None
# 1884  (51.596827149999996, -0.3373046180437286, 0.0)
# 1885          (51.3550556, -0.0643103753173489, 0.0)
# 1889                   (54.9738474, -1.6131572, 0.0)
# 1892         (51.4893335, -0.14405508452768728, 0.0)
# 1893                   (52.4796992, -1.9026911, 0.0)
# 1894         (51.4893335, -0.14405508452768728, 0.0)
# 1897                   (51.4538022, -2.5972985, 0.0)
# 1900                   (53.7593363, -2.6992717, 0.0)
# 1901                 (43.0059455, -123.8925908, 0.0)
# 1909                   (53.5227681, -1.1335312, 0.0)
# 1912                   (51.4816546, -3.1791934, 0.0)
# 1914                   (51.3474866, -0.1950858, 0.0)
# 1916                    (48.5792153, 5.2466402, 0.0)
# 1917                   (51.4143513, -0.7449925, 0.0)
# 1920                    (51.9165361, 0.9263447, 0.0)
# 1921                   (51.2356068, -0.5732063, 0.0)
# 1922                   (53.3058355, -2.2375778, 0.0)
# 1923                 (43.0059455, -123.8925908, 0.0)
# 1926                                            None
# 1927                                            None
# 1928                   (51.6056908, -1.2467923, 0.0)
# 1929                   (52.6780419, -2.4514273, 0.0)
# 1933                    (51.4923137, -0.263818, 0.0)
#
#                                                 raw_loc
# id
# 1867  {'place_id': 242052818, 'licence': 'Data © Ope...
# 1872  {'place_id': 242052818, 'licence': 'Data © Ope...
# 1873  {'place_id': 280722614, 'licence': 'Data © Ope...
# 1874  {'place_id': 240532913, 'licence': 'Data © Ope...
# 1876  {'place_id': 237575883, 'licence': 'Data © Ope...
# 1881  {'place_id': 241502290, 'licence': 'Data © Ope...
# 1882                                               None
# 1884  {'place_id': 242111003, 'licence': 'Data © Ope...
# 1885  {'place_id': 242419284, 'licence': 'Data © Ope...
# 1889  {'place_id': 237126205, 'licence': 'Data © Ope...
# 1892  {'place_id': 242052818, 'licence': 'Data © Ope...
# 1893  {'place_id': 241099099, 'licence': 'Data © Ope...
# 1894  {'place_id': 242052818, 'licence': 'Data © Ope...
# 1897  {'place_id': 243530548, 'licence': 'Data © Ope...
# 1900  {'place_id': 239554062, 'licence': 'Data © Ope...
# 1901  {'place_id': 280722614, 'licence': 'Data © Ope...
# 1909  {'place_id': 240270098, 'licence': 'Data © Ope...
# 1912  {'place_id': 243415102, 'licence': 'Data © Ope...
# 1914  {'place_id': 242411210, 'licence': 'Data © Ope...
# 1916  {'place_id': 103533771, 'licence': 'Data © Ope...
# 1917  {'place_id': 242829363, 'licence': 'Data © Ope...
# 1920  {'place_id': 85530579, 'licence': 'Data © Open...
# 1921  {'place_id': 242884249, 'licence': 'Data © Ope...
# 1922  {'place_id': 239225419, 'licence': 'Data © Ope...
# 1923  {'place_id': 280722614, 'licence': 'Data © Ope...
# 1926                                               None
# 1927                                               None
# 1928  {'place_id': 243043234, 'licence': 'Data © Ope...
# 1929  {'place_id': 239107248, 'licence': 'Data © Ope...
# 1933  {'place_id': 242260465, 'licence': 'Data © Ope...

# %%
test['raw_loc'].loc[1920]
# Out:
# {'place_id': 85530579,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 107900524,
#  'lat': '51.9165361',
#  'lon': '0.9263447',
#  'class': 'highway',
#  'type': 'unclassified',
#  'place_rank': 26,
#  'importance': 0.10000999999999993,
#  'addresstype': 'road',
#  'name': 'Phoenix Square',
#  'display_name': 'Phoenix Square, Colchester Business Park, Highwoods, Colchester, Essex, England, CO4 9HR, United Kingdom',
#  'address': {'road': 'Phoenix Square',
#   'industrial': 'Colchester Business Park',
#   'suburb': 'Highwoods',
#   'city': 'Colchester',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CO4 9HR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  'boundingbox': ['51.9155857', '51.9174571', '0.9254837', '0.9270890']}

# %%
def get_settlement(raw_loc):
    try:
        address = raw_loc['address']
    except:
        return None
    try:
        return address['town']
    except:
        try:
            return address['village']
        except:
            try:
                return address['city']
            except:
                return None

# %%
def get_state(raw_loc):
    try:
        address = raw_loc['address']
        return address['state']
    except:
        return None

# %%
def get_country(raw_loc):
    try:
        address = raw_loc['address']
        return address['country_code']
    except:
        return None

# %%
test['settlement'] = test['raw_loc'].apply(get_settlement)
test['state'] = test['raw_loc'].apply(get_state)
test['country'] = test['raw_loc'].apply(get_country)

# %%
test[['location', 'settlement']].tail(30)
# Out:
#                                      location           settlement
# id
# 1867                                   London               London
# 1872                                   London               London
# 1873                                   Remote                 None
# 1874                               Nottingham   City of Nottingham
# 1876                           United Kingdom                 None
# 1881                       Welwyn Garden City   Welwyn Garden City
# 1882  The Minstry, 79-81 Borough Road, London                 None
# 1884                                   Harrow               London
# 1885                                  Croydon               London
# 1889                      Newcastle upon Tyne  Newcastle upon Tyne
# 1892                                   London               London
# 1893                               Birmingham           Birmingham
# 1894                                   London               London
# 1897                                  Bristol              Bristol
# 1900                                  Preston              Preston
# 1901                                   Remote                 None
# 1909                                Doncaster            Doncaster
# 1912                                  Cardiff              Cardiff
# 1914                 15 Cotswold Road, Sutton               London
# 1916                                   Morley               Morley
# 1917                                Bracknell            Bracknell
# 1920             4 Phoenix Square, Colchester           Colchester
# 1921                                Guildford            Guildford
# 1922                            Alderley Edge        Alderley Edge
# 1923                                   Remote                 None
# 1926        4it Recruitment Ltd in Manchester                 None
# 1927    prosperIS Recruitment Ltd in Monmouth                 None
# 1928                                   Didcot               Didcot
# 1929                                  Telford              Telford
# 1933                                 Chiswick             Chiswick

# %%
test['settlement'].unique()
# Out:
# array(['Cirencester', 'London', 'Manchester', None, 'Bristol',
#        'Cambridge', 'Genève', 'Leeds', 'Brixworth', 'Glasgow', 'Stank',
#        'Lancaster', 'Broad Oak', 'Brough', 'Frimley', 'Filton',
#        'Weymouth', 'Prestwick', 'Chippenham', 'Pontyclun', 'Leatherhead',
#        'Redditch', 'Trafford', 'Cheltenham', 'Solihull', 'Brighton',
#        'Malvern Hills', 'Chiswick', 'Luton', 'City of Edinburgh',
#        'Basildon', 'Southampton', 'Leicester', 'Oxford', 'Bridgend',
#        'Burton-on-Trent', 'Silverstone', 'Shipley', 'Poole', 'Newport',
#        'Newcastle upon Tyne', 'Norwich', 'Hemel Hempstead', 'Bath',
#        'Reading', 'Milton Keynes', 'Dublin', 'Eastbourne',
#        'Wolverhampton', 'Fareham', 'East Kilbride', 'Thame', 'Birmingham',
#        'Gravesend', 'Aylesbury', 'Sandhurst', 'Liverpool',
#        'Stratford-upon-Avon', 'Plymouth', 'Rosyth', 'Stowmarket',
#        'Pencoed', 'Cardiff', 'Telford', 'Worthing', 'Exeter', 'Stroud',
#        'Belfast', 'Bollington', 'Andover', 'Maidstone', 'Cramlington',
#        'Tiverton', 'Bradford', 'Waterlooville', 'Banbury', 'Swindon',
#        'City of Westminster', 'Marlow', 'Halifax', 'Kingston upon Thames',
#        'Swansea', 'Killingworth', 'Hove', 'Great Yarmouth', 'Elmbridge',
#        'Rugby', 'Sheffield', 'Twickenham', 'Gillingham', 'Hempstead',
#        'Royal Tunbridge Wells', 'Hull', 'Guildford', 'Warwick',
#        'Caterham', 'Boston', 'Filey', 'Peterborough', 'Basingstoke',
#        'City of Nottingham', 'Witney', 'Kinson', 'Metchley', 'Milton',
#        'Rickmansworth', 'Stirling', 'Harwell', 'Horsham',
#        'City of London', 'Coventry', 'Southall', 'Farnborough',
#        'Aberdeen City', 'Dundee', 'Park Central', 'Hebden Bridge',
#        'Southport', "King's Lynn", 'Chard', 'Cockermouth',
#        'Carrickfergus', 'Belper CP', 'Newmarket', 'Stoke-on-Trent',
#        'St Albans', 'Yeovil', 'Bolton', 'Hartlebury', 'Penryn',
#        'Portsmouth', 'Hounslow', 'Guiseley', 'Colwyn Bay', 'Bangor',
#        'Inverkeithing', 'Hursley', 'Salisbury', 'Redruth', 'Preston',
#        'Havant', 'Loughborough', 'Woking', 'Camden Town', 'Northwich',
#        'Kings Langley', 'Tiranë', 'Sunderland', 'Lincoln', 'Esher',
#        'Northampton', 'Stevenage', 'Derby', 'Dumfries', 'Theale',
#        'Skipton', 'Rhyl', 'Gateshead', 'Blackburn', 'Croydon', 'Winnersh',
#        'Bracknell', 'High Wycombe', 'Southend-on-Sea', 'High Peak',
#        'Staines-upon-Thames', 'Royal Leamington Spa', 'Lytham St Annes',
#        'Histon', 'Harston', 'Epsom', 'Culham', 'Colchester', 'Gloucester',
#        'Hessle', 'Ilford', 'Elstree', 'Brighouse', 'Camberley',
#        'Kidlington', 'Hook', 'Middlesbrough', 'Gaydon', 'Ipswich',
#        'Hatfield', 'Swadlincote', 'Whitchurch', 'Basingstoke and Deane',
#        'Newbury', 'Henley-on-Thames', 'Richmond', 'Cambourne',
#        'Welwyn Garden City', 'Doncaster', 'Morley', 'Alderley Edge',
#        'Didcot'], dtype=object)

# %%
test['settlement'].value_counts(sort=True).head(20)
# Out:
# settlement
# London                 335
# Cambridge               38
# Leeds                   38
# Manchester              36
# Genève                  36
# Bristol                 17
# City of Edinburgh       16
# Bridgend                14
# Oxford                  12
# Birmingham              11
# Glasgow                 11
# Newcastle upon Tyne     10
# Stank                   10
# Belfast                  8
# Reading                  8
# Liverpool                7
# Southampton              7
# Bollington               6
# Luton                    5
# Stoke-on-Trent           5
# Name: count, dtype: int64

# %%
test.loc[test['settlement'] == 'Stank', 'raw_loc'].iloc[0]
# Out:
# {'place_id': 239373006,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 176965,
#  'lat': '54.128879600000005',
#  'lon': '-3.2269008205428933',
#  'class': 'boundary',
#  'type': 'historic:administrative',
#  'place_rank': 25,
#  'importance': 0.5067591574273398,
#  'addresstype': 'historic:administrative',
#  'name': 'Barrow-in-Furness',
#  'display_name': 'Barrow-in-Furness, Stank, Westmorland and Furness, England, United Kingdom',
#  'address': {'historic:administrative': 'Barrow-in-Furness',
#   'village': 'Stank',
#   'county': 'Westmorland and Furness',
#   'ISO3166-2-lvl6': 'GB-WES',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  'boundingbox': ['54.0396284', '54.2184678', '-3.3248213', '-3.1242815']}

# %%
test['state'].unique()
# Out:
# array(['England', None, 'Genève', 'województwo mazowieckie',
#        'Alba / Scotland', 'Georgia', 'Cymru / Wales', 'Kansas', 'Oregon',
#        'Rhode Island', '香港 Hong Kong',
#        'Northern Ireland / Tuaisceart Éireann', 'Minnesota',
#        'Mecklenburg-Vorpommern', 'Nova Scotia', 'Illinois',
#        'Massachusetts', 'Florida', 'Nouvelle-Aquitaine', 'Maine',
#        'Alabama', 'Shqipëria Qendrore', 'Nebraska', 'North Carolina',
#        'Virginia', 'Grand Est'], dtype=object)

# %%
test['country'].unique()
# Out:
# array(['gb', None, 'ch', 'pl', 'us', 'jp', 'ie', 'cn', 'de', 'ca', 'fr',
#        'hu', 'al'], dtype=object)

# %%
test.loc[test['country'] == 'al']
# Out:
#      website_id  company_id                  title      location  \
# id
# 660           2         308  Data Engineer (Azure)  North London
#
#                           pay  \
# id
# 660  £60,000 - £75,000 a year
#
#                                            description   timestamp  \
# id
# 660  Data Engineer Wanted: Join the Gaming Revoluti...  2024-06-28
#
#             company_name                                           full_loc  \
# id
# 660  Metrica Recruitment  (North london, Rruga Muhamet Gjollesha, 21 Dhj...
#
#                             point  \
# id
# 660  (41.332052, 19.8048247, 0.0)
#
#                                                raw_loc settlement  \
# id
# 660  {'place_id': 81057678, 'licence': 'Data © Open...     Tiranë
#
#                   state country
# id
# 660  Shqipëria Qendrore      al
