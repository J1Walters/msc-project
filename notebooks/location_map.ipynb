# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sqlean as sqlite3
from functools import partial
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# ### Import Data

# %%
DATABASE_PATH = 'C:/University/6G7V0007_MSC_Project/Project/Data/joblistings_transformed_OG_05072024.db'
con = sqlite3.connect(DATABASE_PATH)

# %%
job = pd.read_sql('SELECT * FROM job', con)
company = pd.read_sql('SELECT * FROM company', con)
website = pd.read_sql('SELECT * FROM website', con)
# Out:
# C:\Users\walte\AppData\Local\Temp\ipykernel_12644\1361633401.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   job = pd.read_sql('SELECT * FROM job', con)
# C:\Users\walte\AppData\Local\Temp\ipykernel_12644\1361633401.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   company = pd.read_sql('SELECT * FROM company', con)
# C:\Users\walte\AppData\Local\Temp\ipykernel_12644\1361633401.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   website = pd.read_sql('SELECT * FROM website', con)

# %%
job.set_index('id', inplace=True)
company.set_index('id', inplace=True)
website.set_index('id', inplace=True)

# %%
test = job.merge(company, left_on='company_id', right_index=True)

# %%
test.rename(columns={'name':'company_name'}, inplace=True)

# %%
test.tail(10)
# Out:
#       website_id  company_id                                            title  \
# id
# 1917           2         671                                  Product Manager
# 1920           2         672                               Software Architect
# 1921           2         673       Graduate Technology Consultant - PhD Level
# 1922           2         674                                       BI Analyst
# 1923           2         675                             Full Stack Developer
# 1926           2         676                                 Network Engineer
# 1927           2         677                        Senior Software Developer
# 1928           2         678               Junior Systems Engineer (UK-based)
# 1929           2         679                     Engineer (Test & Validation)
# 1933           2         680  IT Resource Planning & Capacity Support Analyst
#
#                                    location                             pay  \
# id
# 1917                              Bracknell        £41,000 - £59,000 a year
# 1920       4 Phoenix Square, Colchester CO4        £52,000 - £65,000 a year
# 1921                              Guildford                  £34,000 a year
# 1922                          Alderley Edge                            NULL
# 1923                                 Remote  £45,397.82 - £55,353.46 a year
# 1926      4it Recruitment Ltd in Manchester            Up to £55,000 a year
# 1927  prosperIS Recruitment Ltd in Monmouth        £40,000 - £50,000 a year
# 1928                                 Didcot                            NULL
# 1929                            Telford TF7        £26,000 - £36,000 a year
# 1933                               Chiswick                            NULL
#
#                                             description   timestamp  \
# id
# 1917  Product Manager – Bracknell – Hybrid – Up to £...  2024-07-05
# 1920  Nordson Test & Inspection, a leading provider ...  2024-07-05
# 1921  This hugely successful and rapidly expanding c...  2024-07-05
# 1922  CurrentBody is seeking a BI Analyst to join ou...  2024-07-05
# 1923  Please visit our website before applying https...  2024-07-05
# 1926  Network Engineer – Palo Alto/Cisco - £55k – Ma...  2024-07-05
# 1927  *Are you a experienced Software Developer who'...  2024-07-05
# 1928  Work location: United Kingdom, England, Didcot...  2024-07-05
# 1929  ENGINEERING TECHNICIAN: TEST & VALIDATION JOB ...  2024-07-05
# 1933  Great that you're thinking about a career with...  2024-07-05
#
#                      company_name
# id
# 1917   Step Ahead Recruitment Ltd
# 1920                      Nordson
# 1921  Graduate Recruitment Bureau
# 1922                  CurrentBody
# 1923            PureCode Software
# 1926          4it Recruitment Ltd
# 1927    prosperIS Recruitment Ltd
# 1928                      D-Orbit
# 1929           VA Technology Ltd.
# 1933                          BSI

# %%
test.loc[test['location'].str.contains('Morley')]
# Out:
#       website_id  company_id             title     location  \
# id
# 1916           2         670  Manual Test Lead  Morley LS27
#
#                       pay                                        description  \
# id
# 1916  From £57,500 a year  At Evri we understand that searching for your ...
#
#        timestamp company_name
# id
# 1916  2024-07-05         Evri

# %% [markdown]
# ### Clean location

# %%
# Remove mentions of hybrid in location
test['location'].replace(r'\(Hybrid\)', '', regex=True, inplace=True)

# %%
# Remove first line of address
test['location'].replace(r'[0-9]*[a-zA-Z\s]*\,', '', regex=True, inplace=True)

# %%
# Strip whitespace
test['location'] = test['location'].str.strip()

# %%
# Map multiple locations to separate category
test['location'].replace(r'.*\sand\s.*', 'Multiple Locations', regex=True, inplace=True)
test['location'].replace(r'.*\s[&+]\s.*', 'Multiple Locations', regex=True, inplace=True)
test['location'].replace('Multiple UK Locations', 'Multiple Locations', inplace=True)
test['location'].replace('Multiple Worldwide Locations', 'Multiple Locations', inplace=True)

# %%
test['location'].unique()
# Out:
# array(['Cirencester (Gloucestershire)', 'London', 'Manchester',
#        'Multiple Locations', 'Bristol', 'Cambridge',
#        'Geneva (Switzerland)', 'Leeds', 'Warsaw (Poland)',
#        'Brixworth (Northamptonshire)', 'Glasgow',
#        'Broad Oak (Dorchester)', 'Barrow-in-Furness (Cumbria)',
#        'Filton (Bristol)', 'Broad Oak (Portsmouth)', 'Frimley (Surrey)',
#        'Weymouth (Dorset)', 'Barrow (Cumbria)', 'Brough (Hull)',
#        'Prestwick (South Ayrshire)', 'Barrow-In-Furness', 'Brough',
#        'Chippenham (Wiltshire)', 'Pontyclun (South Wales)',
#        'Leatherhead (Surrey)', 'Pontyclun (Wales)',
#        'Redditch (Worcestershire)', 'Trafford Park (Manchester)',
#        'Stafford (West Midlands)', 'Cheltenham (Gloucestershire)',
#        'Didsbury (Manchester)', 'Solihull', 'Brighton', 'Remote',
#        'Malvern Hills (Worcestershire)', 'Chiswick (London)',
#        'Chiswick Park', 'Luton (Bedfordshire)', 'Edinburgh',
#        'Basildon (Essex)', 'Southampton', 'Leicester', 'Oxford',
#        'Tokyo (Japan)', 'Bridgend', 'Burton', 'Silverstone (Northampton)',
#        'Derby', 'Shipley (West Yorkshire)', 'Poole', 'Newport',
#        'Newcastle', 'Norwich', 'West Midlands',
#        'Hemel Hempstead (Hertfordshire)', 'Bath', 'Reading',
#        'Crownhill (Milton Keynes)', 'Dublin', 'Eastbourne (East Sussex)',
#        'Heathrow (London)', 'Uxbridge (West London)', 'Wolverhampton',
#        'Fareham (Hampshire)', 'East Kilbride (Glasgow)',
#        'Thame (Oxfordshire)', 'Birmingham', 'Gravesend',
#        'Aylesbury (Buckinghamshire)', 'Sandhurst (Berkshire)',
#        'Liverpool', 'Stratford-upon-Avon', 'Plymouth', 'Rosyth',
#        'Hong Kong (China)', 'Stowmarket (Suffolk)',
#        'Pencoed (South Wales)', 'Cardiff', 'Newcastle University',
#        'Telford', 'Cheltenham', 'Durrington (West Sussex)',
#        'Beckington (Somerset)', 'Exeter', 'Woodchester (Gloucestershire)',
#        'Belfast', 'Bollington (Cheshire)', 'Andover (Hampshire)',
#        'Cramlington (Northumberland)', 'Devon', 'Hull', 'Bradford',
#        'London W6', 'Waterlooville PO7', 'Banbury', 'Swindon',
#        'London SE1', 'London W1W', 'Marlow', 'Halifax',
#        'Kingston upon Thames', 'London EC1R', 'Swansea',
#        'RG United Kingdom', 'Killingworth NE12', 'Hove BN3', 'London NW1',
#        'Great Yarmouth', 'Thames Ditton KT7', 'Rugby CV21', 'Sheffield',
#        'Twickenham', 'Be Amazed Media Ltd in London', 'Gillingham ME8',
#        'Gillingham', 'Halifax HX3', 'London NW10', "Ray' London NW10",
#        'Royal Tunbridge Wells TN4', 'Kingston upon Hull', 'Brighton BN1',
#        'NETbuilder in Brighton BN1', 'Guildford', 'Livingston',
#        'Warwick CV34', 'Caterham', 'Bristol BS1', 'West End', 'Leeds LS1',
#        'Filey', 'Peterborough PE1', 'Basingstoke', 'Nottingham NG11',
#        'Witney OX28', 'Bournemouth BH7', 'Glasgow G2', 'Canary Wharf E14',
#        'London EC4Y', '33489- 311- G2  Glasgow G2', 'Wembley HA9',
#        '401-  Wembley HA9', 'Birmingham B7', 'Milton OX14',
#        'Manchester M4', 'Liverpool L3', 'Norwich NR5', 'Leeds LS15',
#        'Rickmansworth', 'Biggin Hill', 'London WC1N', 'WC1N  London WC1N',
#        'London EC4V', 'Stirling FK8', 'Wallace House 17- Stirling FK8',
#        'Vintners’  London EC4V', 'Harwell', 'Horsham RH12', 'London EC3A',
#        'Coventry', 'Southall UB1', 'Farringdon', 'Farnborough GU14',
#        'Aberdeen AB23', 'Newcastle upon Tyne NE6', 'Dundee',
#        'Chippenham SN14', 'London EC1N', 'London EC4N', 'Birmingham B16',
#        'Edinburgh EH2', 'Manchester M3', 'Steeple Langford',
#        'Hebden Bridge', 'Southport', "King's Lynn", 'Cramlington',
#        'Chard', 'Cockermouth', 'Carrickfergus', 'Farnborough',
#        'London E1', 'Cambridge CB2', 'Belper DE56',
#        'Kingston upon Hull HU3', 'Newmarket CB8', 'Stoke-on-Trent',
#        'St Albans', 'Floor   London W6', 'Cornwall', 'Wisley',
#        'Luton LU1', 'Yeovil BA20', 'Basildon SS14',
#        'Newcastle upon Tyne NE4', 'Bolton', 'London E14', 'Chippenham',
#        'Hartlebury DY10', 'Unit  Hartlebury DY10', 'Penryn', 'Portsmouth',
#        'Hounslow', 'Guiseley', 'London W1T', 'Colwyn Bay', 'Bangor',
#        'Inverkeithing KY11', 'Budapest', 'Hursley', 'Belfast BT1',
#        'Salisbury SP3', 'Derby DE24', 'United Kingdom', 'Redruth',
#        'Kensington W8', 'Preston', 'Newcastle upon Tyne', 'Havant',
#        'Loughborough', 'London EC2V', 'Woking', 'Hammersmith',
#        'Bolton BL3', 'London EC3R', 'Oxford OX3', 'Belfast BT2',
#        'Northwich CW9', 'Kings Langley WD4', 'Peterborough',
#        'Aberdeen AB11', 'Saint Ives',
#        'Point Professional Recruitment Ltd in Saint Ives', 'North London',
#        'Cardiff CF10', 'Sunderland', 'Lincoln', 'Esher', 'Hyde SK14',
#        'Wales', 'London EC1V', 'Northampton NN4', 'London N1C',
#        'Stevenage SG1', 'London WC1A', 'Sheffield S1', 'Derby DE1',
#        'Oxford OX1', 'London EC2N', 'Dumfries', 'Theale', 'Skipton BD23',
#        'Fulham SW6', 'Rhyl', 'Manchester M30', 'Stevenage', 'Surbiton',
#        'Preston DT3', 'Birmingham B18', 'York', 'M4  Manchester M4',
#        'Gateshead NE10', 'Gateshead', 'Blackburn', 'Croydon CR9',
#        'Winnersh', 'London EC3N', 'Nottingham', 'Bracknell RG12',
#        'Lancaster', 'Oxford OX2', 'London EC2A', 'High Wycombe',
#        'Warrington WA3', 'Dumfries DG1', 'Basildon', 'Southend-on-Sea',
#        'London WC2N', '1- London WC2N', 'Wokingham', 'Derwent',
#        'Leeds LS10', 'Cardiff CF24', 'Staines-upon-Thames',
#        'Milton Keynes', 'Leamington Spa', 'Lytham St. Annes',
#        'London W1K', 'Prudhoe', 'Douglas', 'London N19',
#        'EC1V  London EC1V', 'Bristol BS2', 'Histon CB24', 'London W1U',
#        'Harston CB22', 'Derby DE21', 'Warton', 'Hemel Hempstead HP2',
#        'London EC1M', 'Epsom', 'Fife', 'Culham', 'Wainbody CV3',
#        'Fareham', 'Heathrow', 'Colchester', 'Manchester M2', 'Scotland',
#        'Quedgeley', 'Edinburgh EH3', 'Hessle HU13', 'London E3',
#        'Sunderland SR3', 'Ilford IG6', 'London EC2M', 'Elstree',
#        'Aylesbury', 'Aberdeen', 'Cambridge CB1', 'Hemel Hempstead',
#        'Brighouse HD6', 'Camberley', 'London EC1Y', 'Milton Keynes MK9',
#        'Kidlington', 'Hook', 'Guildford GU1', 'Leicester LE4',
#        'Aberdeen AB12', 'Middlesbrough TS1', 'Gaydon',
#        'Ipswich (Suffolk)', 'Manchester M16', 'Stockton-on-Tees',
#        'V-Teck UK Ltd in Bridgend CF31', 'Glasgow G3', 'Paddington',
#        'Capua HR Limited in London', 'Soho W1F', 'Hatfield',
#        'Technical Resources in Bootle L30', 'Swadlincote DE11',
#        'Altrincham WA14', 'PlayAIO ltd in London', 'Whitchurch SY13',
#        'MLN Security in Barking IG11', 'Mercuna in Edinburgh', 'Tadley',
#        'guykat solutions ltd. Birmingham B7', 'Newbury',
#        'Unit  Barnsley S72', 'Manchester M1', 'Flat   London W1S',
#        'Barrow-In-Furness LA13', 'Henley on Thames',
#        'Oxbridge International College Ltd in Stevenage SG1', 'Richmond',
#        'Liverpool L7', 'Cambourne', 'Nottingham NG8',
#        'Welwyn Garden City', '79- London SE1', 'Harrow', 'Croydon CR0',
#        'Newcastle upon Tyne NE1', 'Doncaster', 'Sutton SM2',
#        'Morley LS27', 'Bracknell', 'Colchester CO4', 'Alderley Edge',
#        '4it Recruitment Ltd in Manchester',
#        'prosperIS Recruitment Ltd in Monmouth', 'Didcot', 'Telford TF7',
#        'Chiswick'], dtype=object)

# %%
test['location'].value_counts(sort=True).head(25)
# Out:
# location
# London                         245
# Remote                          86
# Multiple Locations              84
# Geneva (Switzerland)            36
# Leeds                           32
# Cambridge                       31
# Manchester                      25
# London EC4N                     20
# Bristol                         15
# Bridgend                        14
# Edinburgh                       13
# Budapest                        12
# Birmingham                      10
# Oxford                           9
# Douglas                          8
# Southampton                      7
# Glasgow                          7
# Reading                          7
# Bollington (Cheshire)            6
# Barrow-in-Furness (Cumbria)      6
# London SE1                       6
# Liverpool                        6
# Swindon                          5
# Newcastle upon Tyne              5
# Stafford (West Midlands)         5
# Name: count, dtype: int64

# %%
# Remove entries where location is in Switzerland, Japan, Poland, Cbina or Budapest 
test = test.loc[~test['location'].str.contains('Switzerland|Japan|Budapest|Poland|China')]

# %%
test['location'].value_counts(sort=True).head(25)
# Out:
# location
# London                          245
# Remote                           86
# Multiple Locations               84
# Leeds                            32
# Cambridge                        31
# Manchester                       25
# London EC4N                      20
# Bristol                          15
# Bridgend                         14
# Edinburgh                        13
# Birmingham                       10
# Oxford                            9
# Douglas                           8
# Reading                           7
# Southampton                       7
# Glasgow                           7
# Barrow-in-Furness (Cumbria)       6
# Bollington (Cheshire)             6
# Liverpool                         6
# London SE1                        6
# Stoke-on-Trent                    5
# Stafford (West Midlands)          5
# Newcastle upon Tyne               5
# Manchester M4                     5
# Brixworth (Northamptonshire)      5
# Name: count, dtype: int64

# %%
# Define geocoder objects
geolocator = Nominatim(user_agent='msc_project')
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
# Get full location with geocoder
test['full_loc'] = test['location'].apply(partial(geocode, language='en', addressdetails=True))
test.loc[test['location'].isin(['Remote', 'Multiple Locations']), 'full_loc'] = None

# %%
# Get latitude and longitude
test['lat'] = test['full_loc'].apply(lambda x: x.latitude if x else None)
test['long'] = test['full_loc'].apply(lambda x: x.longitude if x else None)

# %%
# Get raw location data
test['raw_loc'] = test['full_loc'].apply(lambda x: x.raw if x else None)

# %%
test[['location', 'full_loc', 'lat', 'long', 'raw_loc']].tail(30)
# Out:
#                                    location  \
# id
# 1867                            London EC3N
# 1872                                 London
# 1873                                 Remote
# 1874                         Nottingham NG8
# 1876                         United Kingdom
# 1881                     Welwyn Garden City
# 1882                         79- London SE1
# 1884                                 Harrow
# 1885                            Croydon CR0
# 1889                Newcastle upon Tyne NE1
# 1892                                 London
# 1893                             Birmingham
# 1894                                 London
# 1897                                Bristol
# 1900                                Preston
# 1901                                 Remote
# 1909                              Doncaster
# 1912                                Cardiff
# 1914                             Sutton SM2
# 1916                            Morley LS27
# 1917                              Bracknell
# 1920                         Colchester CO4
# 1921                              Guildford
# 1922                          Alderley Edge
# 1923                                 Remote
# 1926      4it Recruitment Ltd in Manchester
# 1927  prosperIS Recruitment Ltd in Monmouth
# 1928                                 Didcot
# 1929                            Telford TF7
# 1933                               Chiswick
#
#                                                full_loc        lat      long  \
# id
# 1867  (Royal Mail, Crosswall, Aldgate, City of Londo...  51.511505 -0.077226
# 1872  (London, Greater London, England, United Kingd...  51.507446 -0.127765
# 1873                                               None        NaN       NaN
# 1874  (NG8 292D, Nuthall Gardens, Whitemoor, Notting...  52.971066 -1.187053
# 1876         (United Kingdom, (54.7023545, -3.2765753))  54.702354 -3.276575
# 1881  (Welwyn Garden City, Welwyn Hatfield, Hertford...  51.803108 -0.206887
# 1882                                               None        NaN       NaN
# 1884  (London Borough of Harrow, London, Greater Lon...  51.596827 -0.337305
# 1885  (Royal Mail, Commerce Way, Waddon, London Boro...  51.374417 -0.119376
# 1889  (Royal Mail, South Street, Grainger Town, Newc...  54.967667 -1.615234
# 1892  (London, Greater London, England, United Kingd...  51.507446 -0.127765
# 1893  (Birmingham, West Midlands Combined Authority,...  52.479699 -1.902691
# 1894  (London, Greater London, England, United Kingd...  51.507446 -0.127765
# 1897  (Bristol, City of Bristol, West of England, En...  51.453802 -2.597298
# 1900  (Preston, Lancashire, England, United Kingdom,...  53.759336 -2.699272
# 1901                                               None        NaN       NaN
# 1909  (Doncaster, South Yorkshire, England, United K...  53.522768 -1.133531
# 1912  (Cardiff, Wales, CF10 2AF, United Kingdom, (51...  51.481655 -3.179193
# 1914  (SM2 110, Crossways, Carshalton Beeches, Londo...  51.351623 -0.183841
# 1916  (LS27 3, Peacock Green, Morley, Tingley, Leeds...  53.743180 -1.583518
# 1917  (Bracknell, Bracknell Forest, England, United ...  51.414351 -0.744992
# 1920  (CO4 320D, Nayland Road, Myland, Mile End, Col...  51.913426  0.891176
# 1921  (Guildford, Surrey, England, United Kingdom, (...  51.235607 -0.573206
# 1922  (Alderley Edge, Cheshire East, England, United...  53.305836 -2.237578
# 1923                                               None        NaN       NaN
# 1926                                               None        NaN       NaN
# 1927                                               None        NaN       NaN
# 1928  (Didcot, East Hagbourne, South Oxfordshire, Ox...  51.605691 -1.246792
# 1929  (TF7 136D, Ironbridge Road, Woodside, Madeley,...  52.632866 -2.472373
# 1933  (Chiswick, Greater London, England, W4 5PS, Un...  51.492314 -0.263818
#
#                                                 raw_loc
# id
# 1867  {'place_id': 243623237, 'licence': 'Data © Ope...
# 1872  {'place_id': 243408926, 'licence': 'Data © Ope...
# 1873                                               None
# 1874  {'place_id': 243353141, 'licence': 'Data © Ope...
# 1876  {'place_id': 239127902, 'licence': 'Data © Ope...
# 1881  {'place_id': 244236001, 'licence': 'Data © Ope...
# 1882                                               None
# 1884  {'place_id': 242260157, 'licence': 'Data © Ope...
# 1885  {'place_id': 244907691, 'licence': 'Data © Ope...
# 1889  {'place_id': 387107161, 'licence': 'Data © Ope...
# 1892  {'place_id': 243408926, 'licence': 'Data © Ope...
# 1893  {'place_id': 243595575, 'licence': 'Data © Ope...
# 1894  {'place_id': 243408926, 'licence': 'Data © Ope...
# 1897  {'place_id': 245300408, 'licence': 'Data © Ope...
# 1900  {'place_id': 241516695, 'licence': 'Data © Ope...
# 1901                                               None
# 1909  {'place_id': 242785973, 'licence': 'Data © Ope...
# 1912  {'place_id': 245917037, 'licence': 'Data © Ope...
# 1914  {'place_id': 242936979, 'licence': 'Data © Ope...
# 1916  {'place_id': 241523982, 'licence': 'Data © Ope...
# 1917  {'place_id': 244478841, 'licence': 'Data © Ope...
# 1920  {'place_id': 389807568, 'licence': 'Data © Ope...
# 1921  {'place_id': 243111677, 'licence': 'Data © Ope...
# 1922  {'place_id': 239649087, 'licence': 'Data © Ope...
# 1923                                               None
# 1926                                               None
# 1927                                               None
# 1928  {'place_id': 243323250, 'licence': 'Data © Ope...
# 1929  {'place_id': 394379314, 'licence': 'Data © Ope...
# 1933  {'place_id': 244836930, 'licence': 'Data © Ope...

# %%
test['raw_loc'].loc[1920]
# Out:
# {'place_id': 389807568,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'node',
#  'osm_id': 11925916885,
#  'lat': '51.913426',
#  'lon': '0.8911755',
#  'class': 'amenity',
#  'type': 'post_box',
#  'place_rank': 30,
#  'importance': 6.33745326924089e-05,
#  'addresstype': 'amenity',
#  'name': 'CO4 320D',
#  'display_name': 'CO4 320D, Nayland Road, Myland, Mile End, Colchester, Essex, England, CO4 5EN, United Kingdom',
#  'address': {'amenity': 'CO4 320D',
#   'road': 'Nayland Road',
#   'suburb': 'Myland',
#   'city': 'Colchester',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CO4 5EN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  'boundingbox': ['51.9133760', '51.9134760', '0.8911255', '0.8912255']}

# %%
def get_settlement(raw_loc):
    try:
        address = raw_loc['address']
    except:
        return None
    try:
        return address['town']
    except:
        try:
            return address['village']
        except:
            try:
                return address['city']
            except:
                return None

# %%
def get_state(raw_loc):
    try:
        address = raw_loc['address']
        return address['state']
    except:
        return None

# %%
def get_country(raw_loc):
    try:
        address = raw_loc['address']
        return address['country_code']
    except:
        return None

# %%
test['settlement'] = test['raw_loc'].apply(get_settlement)
test['state'] = test['raw_loc'].apply(get_state)
test['country'] = test['raw_loc'].apply(get_country)

# %%
test[['location', 'settlement']].tail(30)
# Out:
#                                    location           settlement
# id
# 1867                            London EC3N       City of London
# 1872                                 London               London
# 1873                                 Remote                 None
# 1874                         Nottingham NG8           Nottingham
# 1876                         United Kingdom                 None
# 1881                     Welwyn Garden City   Welwyn Garden City
# 1882                         79- London SE1                 None
# 1884                                 Harrow               London
# 1885                            Croydon CR0               London
# 1889                Newcastle upon Tyne NE1  Newcastle upon Tyne
# 1892                                 London               London
# 1893                             Birmingham           Birmingham
# 1894                                 London               London
# 1897                                Bristol              Bristol
# 1900                                Preston              Preston
# 1901                                 Remote                 None
# 1909                              Doncaster            Doncaster
# 1912                                Cardiff              Cardiff
# 1914                             Sutton SM2               London
# 1916                            Morley LS27               Morley
# 1917                              Bracknell            Bracknell
# 1920                         Colchester CO4           Colchester
# 1921                              Guildford            Guildford
# 1922                          Alderley Edge        Alderley Edge
# 1923                                 Remote                 None
# 1926      4it Recruitment Ltd in Manchester                 None
# 1927  prosperIS Recruitment Ltd in Monmouth                 None
# 1928                                 Didcot               Didcot
# 1929                            Telford TF7              Madeley
# 1933                               Chiswick             Chiswick

# %%
test['settlement'].unique()
# Out:
# array(['Cirencester', 'London', 'Manchester', None, 'Bristol',
#        'Cambridge', 'Leeds', 'Brixworth', 'Glasgow', 'Barrow-in-Furness',
#        'Filton', 'Portsmouth', 'Frimley', 'Weymouth', 'Brantingham',
#        'Prestwick', 'Stank', 'Brough', 'Chippenham', 'Leatherhead',
#        'Pontyclun', 'Redditch', 'Trafford', 'Stafford', 'Cheltenham',
#        'Metropolitan Borough of Solihull', 'Brighton', 'Malvern Hills',
#        'City of Edinburgh', 'Basildon', 'Southampton', 'Leicester',
#        'Oxford', 'Bridgend', 'Burton-on-Trent', 'Derby', 'Shipley',
#        'Poole', 'Newport', 'Newcastle upon Tyne', 'Norwich',
#        'Hemel Hempstead', 'Bath', 'Reading', 'Milton Keynes', 'Dublin',
#        'Eastbourne', 'Wolverhampton', 'Fareham', 'Nerston Village',
#        'Thame', 'Birmingham', 'Gravesend', 'Aylesbury', 'Clermont',
#        'Liverpool', 'Stratford-upon-Avon', 'Plymouth', 'Rosyth',
#        'Stowmarket', 'Cardiff', 'Telford', 'Worthing', 'Exeter', 'Stroud',
#        'Belfast', 'Bollington', 'Andover', 'Cramlington', 'Hull',
#        'Bradford', 'Havant', 'Banbury', 'Swindon', 'City of Westminster',
#        'Marlow', 'Halifax', 'Kingston upon Thames', 'Swansea',
#        'Forest Hall', 'Hove', 'Great Yarmouth', 'Molesey', 'Rugby',
#        'Sheffield', 'Twickenham', 'Rainham', 'Gillingham',
#        'Skircoat Green', 'Royal Tunbridge Wells', 'Guildford',
#        'Stratford-on-Avon', 'Caterham', 'Boston', 'Filey', 'Peterborough',
#        'Basingstoke', 'Nottingham', 'Witney', 'Holdenhurst',
#        'City of London', 'Metchley', 'Milton', 'Rickmansworth',
#        'Gargunnock', 'Harwell', 'Horsham', 'Coventry', 'Farnborough',
#        'Aberdeen City', 'Dundee', 'Park Central', 'Hebden Bridge',
#        'Southport', "King's Lynn", 'Chard', 'Cockermouth',
#        'Carrickfergus', 'Belper CP', 'Newmarket', 'Stoke-on-Trent',
#        'St Albans', 'Luton', 'Yeovil', 'Bolton', 'Hartlebury', 'Penryn',
#        'Hounslow', 'Guiseley', 'Colwyn Bay', 'Bangor', 'Inverkeithing',
#        'Hursley', 'Salisbury', 'Redruth', 'Preston', 'Loughborough',
#        'Woking', 'Northwich', 'Kings Langley', 'Tirana', 'Sunderland',
#        'Lincoln', 'Esher', 'Hyde', 'Northampton', 'Stevenage', 'Dumfries',
#        'Theale', 'Skipton', 'Rhyl', 'York', 'Gateshead', 'Blackburn',
#        'Winnersh', 'Bracknell', 'High Wycombe', 'Kingholm Quay',
#        'Southend-on-Sea', 'High Peak', 'Rothwell', 'Staines-upon-Thames',
#        'Royal Leamington Spa', 'Lytham St Annes', 'Impington', 'Harston',
#        'Lancaster', 'Epsom', 'Culham', 'Colchester', 'Gloucester',
#        'Hessle', 'Ilford', 'Elstree', 'Clifton', 'Camberley',
#        'Kidlington', 'Hook', 'Middlesbrough', 'Gaydon', 'Ipswich',
#        'Stockton-on-Tees', 'Hatfield', 'Swadlincote', 'Altrincham',
#        'Whitchurch', 'Basingstoke and Deane', 'Newbury', 'Penistone',
#        'Wythenshawe', 'Henley-on-Thames', 'Richmond', 'Cambourne',
#        'Welwyn Garden City', 'Doncaster', 'Morley', 'Alderley Edge',
#        'Didcot', 'Madeley', 'Chiswick'], dtype=object)

# %%
test['settlement'].value_counts(sort=True).head(20)
# Out:
# settlement
# London                 312
# Cambridge               38
# Manchester              36
# Leeds                   36
# City of London          31
# Bristol                 17
# City of Edinburgh       16
# Bridgend                15
# Oxford                  12
# Birmingham              11
# Glasgow                 10
# Newcastle upon Tyne     10
# Liverpool                9
# Barrow-in-Furness        8
# Derby                    8
# Belfast                  8
# Reading                  7
# Southampton              7
# Bollington               6
# Stoke-on-Trent           5
# Name: count, dtype: int64

# %%
test.loc[test['settlement'] == 'Stank']
# Out:
#      website_id  company_id                       title           location  \
# id
# 431           2          14  Graduate Software Engineer  Barrow-In-Furness
#
#                 pay                                        description  \
# id
# 431  £34,000 a year  Description Job Title Graduate Submarines Soft...
#
#       timestamp company_name  \
# id
# 431  2024-06-28  BAE Systems
#
#                                               full_loc       lat      long  \
# id
# 431  (Barrow-in-Furness, Stank, Westmorland and Fur...  54.12888 -3.226901
#
#                                                raw_loc settlement    state  \
# id
# 431  {'place_id': 239373006, 'licence': 'Data © Ope...      Stank  England
#
#     country
# id
# 431      gb

# %%
test['state'].value_counts(dropna=False)
# Out:
# state
# England                   837
# None                      213
# Scotland                   41
# Wales                      27
# Northern Ireland            9
# Illinois                    9
# Nouvelle-Aquitaine          2
# Massachusetts               1
# Nebraska                    1
# Central Albania             1
# Alabama                     1
# Maine                       1
# Mecklenburg-Vorpommern      1
# Nova Scotia                 1
# Hong Kong                   1
# KwaZulu-Natal               1
# Rhode Island                1
# Masovian Voivodeship        1
# Virginia                    1
# Name: count, dtype: int64

# %%
test['state'].unique()
# Out:
# array(['England', None, 'Masovian Voivodeship', 'Scotland', 'Wales',
#        'Rhode Island', 'KwaZulu-Natal', 'Hong Kong', 'Northern Ireland',
#        'Mecklenburg-Vorpommern', 'Nova Scotia', 'Illinois',
#        'Massachusetts', 'Nouvelle-Aquitaine', 'Maine', 'Alabama',
#        'Central Albania', 'Nebraska', 'Virginia'], dtype=object)

# %%
test['country'].unique()
# Out:
# array(['gb', None, 'pl', 'us', 'ie', 'za', 'cn', 'de', 'ca', 'fr', 'al'],
#       dtype=object)

# %%
test.loc[test['country'] == 'fr']
# Out:
#       website_id  company_id                        title location  \
# id
# 446            2         189  Graduate Software Developer    Chard
# 1120           2         189      Firmware Graduate (R&D)    Chard
#
#                       pay                                        description  \
# id
# 446   From £29,000 a year  We are seeking a Software Developer Graduate t...
# 1120       £29,000 a year  About Us We are looking for people who enjoy t...
#
#        timestamp                   company_name  \
# id
# 446   2024-06-28  Numatic International Limited
# 1120  2024-06-28  Numatic International Limited
#
#                                                full_loc       lat     long  \
# id
# 446   (Chard, Aubusson, Creuse, Nouvelle-Aquitaine, ...  45.94409  2.47593
# 1120  (Chard, Aubusson, Creuse, Nouvelle-Aquitaine, ...  45.94409  2.47593
#
#                                                 raw_loc settlement  \
# id
# 446   {'place_id': 105785849, 'licence': 'Data © Ope...      Chard
# 1120  {'place_id': 105785849, 'licence': 'Data © Ope...      Chard
#
#                    state country
# id
# 446   Nouvelle-Aquitaine      fr
# 1120  Nouvelle-Aquitaine      fr

# %%
test['settlement'].value_counts()
# Out:
# settlement
# London            312
# Cambridge          38
# Manchester         36
# Leeds              36
# City of London     31
#                  ...
# Newmarket           1
# Belper CP           1
# Carrickfergus       1
# Cockermouth         1
# Chiswick            1
# Name: count, Length: 199, dtype: int64

# %% [markdown]
# ### Plot on map

# %%
import plotly.express as px
import plotly.io as pio

# %%
pio.renderers.default = 'notebook_connected'

# %%
geodf = test.groupby('settlement').agg({'lat':'mean', 'long':'mean', 'settlement':'count'})

# %%
geodf.rename(columns={'settlement':'num_jobs'}, inplace=True)

# %%
fig = px.scatter_mapbox(geodf, lat='lat', lon='long', size='num_jobs', size_max=25, hover_name=geodf.index, zoom=4, mapbox_style='open-street-map')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e95b0729-4055-4c67-81ba-782a330ee5e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e95b0729-4055-4c67-81ba-782a330ee5e8")) {                    Plotly.newPlot(                        "e95b0729-4055-4c67-81ba-782a330ee5e8",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003enum_jobs=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Aberdeen City","Alderley Edge","Altrincham","Andover","Aylesbury","Banbury","Bangor","Barrow-in-Furness","Basildon","Basingstoke","Basingstoke and Deane","Bath","Belfast","Belper CP","Birmingham","Blackburn","Bollington","Bolton","Boston","Bracknell","Bradford","Brantingham","Bridgend","Brighton","Bristol","Brixworth","Brough","Burton-on-Trent","Camberley","Cambourne","Cambridge","Cardiff","Carrickfergus","Caterham","Chard","Cheltenham","Chippenham","Chiswick","Cirencester","City of Edinburgh","City of London","City of Westminster","Clermont","Clifton","Cockermouth","Colchester","Colwyn Bay","Coventry","Cramlington","Culham","Derby","Didcot","Doncaster","Dublin","Dumfries","Dundee","Eastbourne","Elstree","Epsom","Esher","Exeter","Fareham","Farnborough","Filey","Filton","Forest Hall","Frimley","Gargunnock","Gateshead","Gaydon","Gillingham","Glasgow","Gloucester","Gravesend","Great Yarmouth","Guildford","Guiseley","Halifax","Harston","Hartlebury","Harwell","Hatfield","Havant","Hebden Bridge","Hemel Hempstead","Henley-on-Thames","Hessle","High Peak","High Wycombe","Holdenhurst","Hook","Horsham","Hounslow","Hove","Hull","Hursley","Hyde","Ilford","Impington","Inverkeithing","Ipswich","Kidlington","King's Lynn","Kingholm Quay","Kings Langley","Kingston upon Thames","Lancaster","Leatherhead","Leeds","Leicester","Lincoln","Liverpool","London","Loughborough","Luton","Lytham St Annes","Madeley","Malvern Hills","Manchester","Marlow","Metchley","Metropolitan Borough of Solihull","Middlesbrough","Milton","Milton Keynes","Molesey","Morley","Nerston Village","Newbury","Newcastle upon Tyne","Newmarket","Newport","Northampton","Northwich","Norwich","Nottingham","Oxford","Park Central","Penistone","Penryn","Peterborough","Plymouth","Pontyclun","Poole","Portsmouth","Preston","Prestwick","Rainham","Reading","Redditch","Redruth","Rhyl","Richmond","Rickmansworth","Rosyth","Rothwell","Royal Leamington Spa","Royal Tunbridge Wells","Rugby","Salisbury","Sheffield","Shipley","Skipton","Skircoat Green","Southampton","Southend-on-Sea","Southport","St Albans","Stafford","Staines-upon-Thames","Stank","Stevenage","Stockton-on-Tees","Stoke-on-Trent","Stowmarket","Stratford-on-Avon","Stratford-upon-Avon","Stroud","Sunderland","Swadlincote","Swansea","Swindon","Telford","Thame","Theale","Tirana","Trafford","Twickenham","Welwyn Garden City","Weymouth","Whitchurch","Winnersh","Witney","Woking","Wolverhampton","Worthing","Wythenshawe","Yeovil","York"],"lat":[57.14498724,53.3058355,53.3929715,51.2078275,51.8161412,52.0601807,44.8016255,54.102269525000004,51.5718729,51.262826,51.3414473,51.3813864,54.59502523125,53.012574,52.480569813636365,53.749326,53.29348000000001,53.5782863,42.3639186,51.41464715,53.7944229,53.7451183,51.50459271666667,50.82355116,51.45381365294117,52.32440565,54.5266327,52.802742,51.3392845,52.219984,52.20571305,51.48135442,54.7136165,51.2819693,45.94409,51.89956850000001,51.455481999999996,51.4923137,51.7171029,55.9535086125,51.513173661290324,51.5139091,-29.7826894,53.7047081,54.6614392,51.90155815,53.2953269,52.3965254,55.0855893,51.656287,52.9215739875,51.6056908,53.5227681,53.3493795,55.0691397,56.4605938,50.7664372,51.6437729,51.3326098,51.3693938,50.7255794,50.8526637,51.296782,54.2096884,51.52070625,5 ...

# %%
fig = px.density_mapbox(geodf, lat='lat', lon='long', z='num_jobs', opacity=0.9, radius=30, center=dict(lat=52, lon=0), zoom=4, mapbox_style='open-street-map')
fig.show()
# Out:
# <div>                            <div id="af35a61b-cd68-4e6e-826e-68aa813228f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af35a61b-cd68-4e6e-826e-68aa813228f2")) {                    Plotly.newPlot(                        "af35a61b-cd68-4e6e-826e-68aa813228f2",                        [{"coloraxis":"coloraxis","hovertemplate":"num_jobs=%{z}\u003cbr\u003elat=%{lat}\u003cbr\u003elong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[57.14498724,53.3058355,53.3929715,51.2078275,51.8161412,52.0601807,44.8016255,54.102269525000004,51.5718729,51.262826,51.3414473,51.3813864,54.59502523125,53.012574,52.480569813636365,53.749326,53.29348000000001,53.5782863,42.3639186,51.41464715,53.7944229,53.7451183,51.50459271666667,50.82355116,51.45381365294117,52.32440565,54.5266327,52.802742,51.3392845,52.219984,52.20571305,51.48135442,54.7136165,51.2819693,45.94409,51.89956850000001,51.455481999999996,51.4923137,51.7171029,55.9535086125,51.513173661290324,51.5139091,-29.7826894,53.7047081,54.6614392,51.90155815,53.2953269,52.3965254,55.0855893,51.656287,52.9215739875,51.6056908,53.5227681,53.3493795,55.0691397,56.4605938,50.7664372,51.6437729,51.3326098,51.3693938,50.7255794,50.8526637,51.296782,54.2096884,51.52070625,55.0285375,51.3140156,56.1244603,54.95545475,52.183882249999996,51.3871701,55.861155,51.8274128,51.4424747,52.6071742,51.25264157,53.8748297,44.648618,52.1391482,52.3347627,51.5999743,51.7634675,50.8486361,53.7406425,51.753464675000004,51.5375786,53.7196223,53.39788105,51.6317449,50.7451473,51.286321099999995,51.1215314,51.4686132,50.8388618,53.7417263,51.0251858,53.4584142,51.5582734,52.2488136,56.0334756,52.0579324,51.823462,52.7538673,55.0454244,51.727057,51.4096275,54.141878649999995,51.2955038,53.79726878611111,52.639984000000005,40.8088861,53.39486598888889,51.49849596282051,52.7723859,51.8792487,53.7485046,52.6328659,52.1675333,53.477591286111114,54.1556493,52.45413495,52.4130189,54.5709057,51.6299387,52.038699980000004,51.3888202,53.7431801,55.7863773,51.4020243,54.974159355,52.2415061,41.4899827,52.2280613,53.2614442,52.63025555,52.943220700000005,51.755583620833335,52.47906758333334,53.533943050000005,50.1685457,52.57043843333333,50.3714122,51.5251887,50.7179472,50.814514149999994,53.7593363,55.4982802,51.3643564,51.4564242,52.3057655,50.233989,53.3207425,37.5385087,51.6401841,56.0388706,53.7606186,52.2913394,51.1239314,52.3583365,51.0690613,53.3806626,53.8321814,53.9678621,53.7071157,50.9025349,51.5388241,53.6475988,51.753051,52.8060429,51.434012,54.128879600000005,51.91001752,54.564094,53.0162014,52.1878147,52.2191627,52.1927803,51.7186151,54.887417850000006,52.779158,51.6195955,51.5615327,52.6780419,51.7482733,51.2137333,41.332052,53.4717516,51.4467444,51.8031083,50.62436135,52.9709898,51.430882,51.7925099,51.3201891,52.5847651,50.8328041,53.3613342,50.9455684,53.9590555],"lon":[-2.09484084,-2.2375778,-2.3711788,-1.479355,-0.8130383,-1.3402795,-68.7713289,-3.2509685125,0.48305509999999996,-1.0861976,-1.1446781163706068,-2.3596963,-5.9315648515396875,-1.4813486,-1.9035785803302205,-2.4840566,-2.1107855,-2.4300367,-71.0638993,-0.74070975,-1.7519186,-0.5724299045242716,-3.5749889134607016,-0.13982568,-2.5978850176470587,-0.8894063104311261,-2.3179826,-1.629917,-0.7460981,-0.0700777,0.12013512105263159,-3.1773768799999997,-5.8073112,-0.0771032,2.47593,-2.0711559,-2.123981533333333,-0.263818,-1.9661616,-3.1918321375,-0.09165367096774193,-0.1343916,30.8793765,-1.7626521,-3.3590111,0.8953203000000001,-3.7262534,-1.5209441,-1.59069,-1.255071597483023,-1.46718955,-1.2467923,-1.1335312,-6.2605593,-3.6107936,-2.97019,0.2781546,-0.2989349,-0.2678212,-0.365415,-3.5269497,-1.1783134,-0.74853725,-0.2888382,-2.597967816855559,-1.580042,-0.7440667,-4.0825955,-1.5889543,-1.4665136858172174,0 ...
